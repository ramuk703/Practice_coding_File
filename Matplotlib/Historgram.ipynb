# %% [markdown]
# Histogram Plot in Matplotlib of python

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
x = np.random.randint(10,50,(50))
print(x)
x = [10,20,30,40]
# Out:
# [42 28 26 26 45 12 46 24 40 28 35 10 33 16 18 17 24 47 11 14 24 29 43 27
#  27 19 27 45 44 27 43 38 30 10 42 24 46 32 46 33 41 19 29 46 49 35 46 38
#  37 47]

# %%
no =[42 ,28, 26 ,26, 45, 12 ,46 ,24, 40 ,28 ,35 ,10 ,33 ,16 ,18, 17 ,24 ,47 ,11 ,14 ,24 ,29 ,43 ,27,
 27 ,19 ,27 ,45 ,44 ,27, 43 ,38 ,30, 10 ,42, 24, 46, 32 ,46 ,33, 41, 19 ,29 ,46 ,49, 35, 46, 38
 ,37 ,47,]
plt.title("Data arrangement")
plt.ylabel("No of data")
plt.xlabel("Range of Data")
plt.hist(no,width=2,align="mid",edgecolor="red",color="yellow",linewidth=)
plt.show()

# %%
# Graph plot large data arrangement by bins parameters

no =[42 ,28, 26 ,26, 45, 12 ,46 ,24, 40 ,28 ,35 ,10 ,33 ,16 ,18, 17 ,24 ,47 ,11 ,14 ,24 ,29 ,43 ,27,
 27 ,19 ,27 ,45 ,44 ,27, 43 ,38 ,30, 10 ,42, 24, 46, 32 ,46 ,33, 41, 19 ,29 ,46 ,49, 35, 46, 38
 ,37 ,47,]
li=[10,20,30,40,50]
plt.title("Data arrangement")
plt.ylabel("No of data")
plt.xlabel("Range of Data")
plt.hist(no,bins=li,align="mid",edgecolor="red",color="yellow",linewidth=3)
plt.show()

# %%
# Graph plot arrangement parameters in arrange in large amount of data

no =[42 ,28, 26 ,26, 45, 12 ,46 ,24, 40 ,28 ,35 ,10 ,33 ,16 ,18, 17 ,24 ,47 ,11 ,14 ,24 ,29 ,43 ,27,
 27 ,19 ,27 ,45 ,44 ,27, 43 ,38 ,30, 10 ,42, 24, 46, 32 ,46 ,33, 41, 19 ,29 ,46 ,49, 35, 46, 38
 ,37 ,47,]
li=[10,20,30,40,50]
plt.title("Data arrangement")
plt.ylabel("No of data")
plt.xlabel("Range of Data")
plt.hist(no,"auto",(0,100),edgecolor="red",color="yellow",linewidth=3)
plt.show()

# %%
no =[42 ,28, 26 ,26, 45, 12 ,46 ,24, 40 ,28 ,35 ,10 ,33 ,16 ,18, 17 ,24 ,47 ,11 ,14 ,24 ,29 ,43 ,27,
 27 ,19 ,27 ,45 ,44 ,27, 43 ,38 ,30, 10 ,42, 24, 46, 32 ,46 ,33, 41, 19 ,29 ,46 ,49, 35, 46, 38
 ,37 ,47,]
plt.title("Data arrangement")
plt.ylabel("No of data")
plt.xlabel("Range of Data")
plt.hist(no,align="mid",edgecolor="y",color="blue",linewidth=2)
plt.show()

# %%
# Graph plot in deceding order

no =[42 ,28, 26 ,26, 45, 12 ,46 ,24, 40 ,28 ,35 ,10 ,33 ,16 ,18, 17 ,24 ,47 ,11 ,14 ,24 ,29 ,43 ,27,
 27 ,19 ,27 ,45 ,44 ,27, 43 ,38 ,30, 10 ,42, 24, 46, 32 ,46 ,33, 41, 19 ,29 ,46 ,49, 35, 46, 38
 ,37 ,47,]
plt.title("Data arrangement")
plt.ylabel("No of data")
plt.xlabel("Range of Data")
plt.hist(no,align="mid",edgecolor="y",color="red",linewidth=2,cumulative=1)
plt.show()

# %%
# Graph paramter in reverse assending order

no =[42 ,28, 26 ,26, 45, 12 ,46 ,24, 40 ,28 ,35 ,10 ,33 ,16 ,18, 17 ,24 ,47 ,11 ,14 ,24 ,29 ,43 ,27,
 27 ,19 ,27 ,45 ,44 ,27, 43 ,38 ,30, 10 ,42, 24, 46, 32 ,46 ,33, 41, 19 ,29 ,46 ,49, 35, 46, 38
 ,37 ,47,]
plt.title("Data arrangement")
plt.ylabel("No of data")
plt.xlabel("Range of Data")
plt.hist(no,align="mid",edgecolor="r",color="c",linewidth=2,cumulative=-1)
plt.show()

# %%
# graph start in 20 range from bottom

no =[42 ,28, 26 ,26, 45, 12 ,46 ,24, 40 ,28 ,35 ,10 ,33 ,16 ,18, 17 ,24 ,47 ,11 ,14 ,24 ,29 ,43 ,27,
 27 ,19 ,27 ,45 ,44 ,27, 43 ,38 ,30, 10 ,42, 24, 46, 32 ,46 ,33, 41, 19 ,29 ,46 ,49, 35, 46, 38
 ,37 ,47,]
plt.title("Data arrangement")
plt.ylabel("No of data")
plt.xlabel("Range of Data")
plt.hist(no,align="mid",edgecolor="y",color="red",linewidth=2,bottom=20)
plt.show()

# %%
# graph start in 20 range from bottom

no =[42 ,28, 26 ,26, 45, 12 ,46 ,24, 40 ,28 ,35 ,10 ,33 ,16 ,18, 17 ,24 ,47 ,11 ,14 ,24 ,29 ,43 ,27,
 27 ,19 ,27 ,45 ,44 ,27, 43 ,38 ,30, 10 ,42, 24, 46, 32 ,46 ,33, 41, 19 ,29 ,46 ,49, 35, 46, 38
 ,37 ,47,]
plt.title("Data arrangement")
plt.ylabel("No of data")
plt.xlabel("Range of Data")
plt.hist(no,align="mid",edgecolor="r",color="orange",linewidth=2,bottom=20,orientation="horizontal")
plt.show()

# %%
# graph start in 20 range from bottom

no =[42 ,28, 26 ,26, 45, 12 ,46 ,24, 40 ,28 ,35 ,10 ,33 ,16 ,18, 17 ,24 ,47 ,11 ,14 ,24 ,29 ,43 ,27,
 27 ,19 ,27 ,45 ,44 ,27, 43 ,38 ,30, 10 ,42, 24, 46, 32 ,46 ,33, 41, 19 ,29 ,46 ,49, 35, 46, 38
 ,37 ,47,]
plt.title("Data arrangement")
plt.ylabel("No of data")
plt.xlabel("Range of Data")
plt.hist(no,align="mid",edgecolor="r",color="orange",linewidth=2,bottom=20,rwidth=0.8,)
plt.show()

# %%
# graph plot line paramter

no =[42 ,28, 26 ,26, 45, 12 ,46 ,24, 40 ,28 ,35 ,10 ,33 ,16 ,18, 17 ,24 ,47 ,11 ,14 ,24 ,29 ,43 ,27,
 27 ,19 ,27 ,45 ,44 ,27, 43 ,38 ,30, 10 ,42, 24, 46, 32 ,46 ,33, 41, 19 ,29 ,46 ,49, 35, 46, 38
 ,37 ,47,]
plt.title("Data arrangement")
plt.ylabel("No of data")
plt.xlabel("Range of Data")
plt.axvline(30,color="g",label="Line")
plt.axhline(25,color="b",label="Line2")
plt.legend()
plt.hist(no,align="mid",edgecolor="r",color="orange",linewidth=2,bottom=20,)
plt.show()

# %%
# graph plot line paramter

no =[42 ,28, 26 ,26, 45, 12 ,46 ,24, 40 ,28 ,35 ,10 ,33 ,16 ,18, 17 ,24 ,47 ,11 ,14 ,24 ,29 ,43 ,27,
 27 ,19 ,27 ,45 ,44 ,27, 43 ,38 ,30, 10 ,42, 24, 46, 32 ,46 ,33, 41, 19 ,29 ,46 ,49, 35, 46, 38
 ,37 ,47,]
plt.title("Data arrangement")
plt.ylabel("No of data")
plt.xlabel("Range of Data")
plt.axvline(30,color="g",label="Line")
plt.axhline(25,color="b",label="Line2")
plt.legend()
plt.grid()
plt.hist(no,align="mid",edgecolor="r",color="orange",linewidth=2,bottom=20,)
plt.show()
