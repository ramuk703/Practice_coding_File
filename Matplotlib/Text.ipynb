# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6,7,8,9,3]
y = [2,3,5,2,3,5,1,2,4,5]
# y = ["Python","JAVA","C++","C","c#","HTML","CSS","JS","NodeJs","DJango"]
plt.plot(x,y)
plt.xlabel("Days",fontsize=15)
plt.ylabel("Python",fontsize=15)
plt.title("Data Range")
plt.text(4,4,"Ramuk",fontsize=15,style="italic",bbox={"facecolor":"red"})
plt.annotate("python",xy=(4,2),xytext=(9,4),arrowprops=dict(facecolor="black",shrink=100))
plt.show()
