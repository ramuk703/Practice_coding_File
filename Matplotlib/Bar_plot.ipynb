# %% [markdown]
# Bar Plot

# %%
import matplotlib.pyplot as plt
x = ["HTML","CSS","JAVA SCRIPT","C","C++","C#","DBMS"]
y = [89,100,34,53,65,77,65]
plt.xlabel("Language")
plt.ylabel("No.")
plt.title("Programing")
plt.bar(x,y,)
plt.show()
